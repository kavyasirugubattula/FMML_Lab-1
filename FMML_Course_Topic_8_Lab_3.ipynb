# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyasirugubattula/FMML_Lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 12:26:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   177MB/s    in 0.4s
#
# 2024-04-05 12:26:33 (177 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19936   1303.5426v1  This paper describes the architecture of R&D A...    cs
# 16512  1703.05423v1  End-to-end design of dialogue systems has rece...    cs
# 16033  1608.05528v3  This paper is concerned with identifying conte...    cs
# 11258  1506.06100v1  We introduce the Variational Holder (VH) bound...  stat
# 8721   1801.08985v1  We consider the problem of retrieving objects ...    cs
# ...             ...                                                ...   ...
# 25476  1509.04619v1  Good results on image classification and retri...    cs
# 6662   1704.09011v4  The contextual bandit literature has tradition...  stat
# 35663   1102.4922v1  The study of phase transition phenomenon of NP...    cs
# 22636  1703.04046v2  The present study proposes a deep learning mod...  stat
# 13032  1503.05526v1  Detecting early signs of failures (anomalies) ...  stat
#
#                                                    title  year  \
# 19936  R&D Analyst: An Interactive Approach to Normat...  2013
# 16512  End-to-end optimization of goal-driven and vis...  2017
# 16033  Automatic Selection of Context Configurations ...  2016
# 11258  Approximate Inference with the Variational Hol...  2015
# 8721   Object category learning and retrieval with we...  2018
# ...                                                  ...   ...
# 25476  Medical Image Classification via SVM using LBP...  2015
# 6662   Mostly Exploration-Free Algorithms for Context...  2017
# 35663  Counting Solutions of Constraint Satisfiabilit...  2011
# 22636  DeepSleepNet: a Model for Automatic Sleep Stag...  2017
# 13032  Interpretable Aircraft Engine Diagnostic via E...  2015
#
#                                                 keywords
# 19936  [describes, architecture, commercial, intellig...
# 16512  [architectures, approaches, management, superv...
# 16033  [concerned, identifying, representation, diffe...
# 11258  [introduce, variational, alternative, variatio...
# 8721   [retrieving, meaningful, categories, supervisi...
# ...                                                  ...
# 25476  [classification, retrieval, extensively, liter...
# 6662   [contextual, literature, traditionally, algori...
# 35663  [transition, phenomenon, important, understand...
# 22636  [deepsleepnet, automatic, engineered, knowledg...
# 13032  [detecting, preventive, maintenance, particula...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19936    [describes, architecture, commercial, intellig...
# 16512    [architectures, approaches, management, superv...
# 16033    [concerned, identifying, representation, diffe...
# 11258    [introduce, variational, alternative, variatio...
# 8721     [retrieving, meaningful, categories, supervisi...
#                                ...
# 14392    [recognition, linguistic, presented, hierarchi...
# 22838    [fundamental, processing, specifically, challe...
# 5510     [graphical, penalties, precision, thispenalize...
# 2064     [reinforcement, recovering, demonstrations, in...
# 38366    [communities, moderators, indicating, attempte...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8915 words.
# Out of those 4645 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="634f1aed-a6ce-46fc-8a33-ba6c55c67066" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("634f1aed-a6ce-46fc-8a33-ba6c55c67066")) {                    Plotly.newPlot(                        "634f1aed-a6ce-46fc-8a33-ba6c55c67066",                        [{"x":["intelligent","evaluating","requirements","interactive","explicitly","perspective","flexibility","resources","satisfies","describes","portfolios","normative","reasoning","individual","financial","suggesting","involving","extending","architecture","influence","developing","sequential","commercial","construction","decisions","interactively","opportunistic","development","analyzing","explained","blackboard","constructing","encouraging","addressed","management","approaches","collected","supervised","dialogues","answering","optimization","discovering","participant","reinforcement","utterance","predicting","simplistic","algorithm","generating","introduce","architectures","intrinsic","mechanical","framework","concerned","demonstrate","construct","languages","identifying","efficiently","adjectives","efficient","relations","selection","representations","dependency","similarity","configuration","outperform","resulting","configurations","generalise","correlation","effective","particularly","dependencies","representation","universal","previously","automatic","different","approximate","intractable","typically","integration","parameters","algorithms","truncated","minimization","multivariate","approximation","variational","inference","distribution","literature","numerical","integrating","maximization","alternative","experiments","proposals","supervision","embedding","promising","challenging","retrieving","unsupervised","completely","cityscapes","contributions","semantically","objective","represented","currently","correspond","differentiable","clustering","categories","segmentation","retrieval","generation","mechanism","meaningful","unlabeled","objectness","simultaneously","embeddings","dimensional","occurrence","interpretable","interpretability","distinguishes","theoretical","essential","neuroimaging","represent","sufficient","recognition","interpretation","justification","experimental","distinction","depending","prediction","investigates","predictions","sensitive","continuation","techniques","requiring","monitoring","remaining","consistently","outperforms","predictive","completed","certainly","conditional","antecedents","observations","improvement","statements","validated","intuition","hypothetical","counterfactual","antecedent","operations","functions","interested","recurring","variables","automatically","regularization","relevance","stochastic","significantly","contracting","determination","empirical","probabilistic","dimensionality","illustrating","generative","employing","expressive","regression","uncorrelated","principal","responses","predictor","regressors","illustrate","accurately","knowledge","assumption","questions","components","deviations","frequencies"],"y":[60,64,61,44,61,71,33,70,15,85,4,4,123,108,10,13,54,37,240,59,58,66,24,83,60,4,2,117,47,11,2,38,17,34,46,450,67,189,11,44,335,22,5,94,8,79,1,793,100,343,125,38,16,534,20,548,77,106,84,148,5,405,89,169,236,54,153,23,93,133,26,5,77,276,81,60,377,44,98,197,742,107,22,123,56,247,596,5,51,20,111,53,200,207,127,86,37,32,97,621,30,54,104,109,278,8,146,42,2,45,30,173,86,71,28,24,145,73,199,107,140,92,54,39,5,107,75,202,29,24,12,2,142,87,2,118,73,407,55,10,373,3,32,212,29,74,57,4,399,42,41,27,39,264,55,5,3,102,2,80,170,9,35,17,4,3,1,65,204,21,1,125,193,77,41,139,260,1,16,135,175,65,3,130,42,33,120,1,31,24,11,7,65,64,349,56,49,112,10,11],"type":"bar"},{"x":["intelligent","evaluating","requirements","interactive","explicitly"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4645,), (4645, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Real</span> <span style=''>time</span> <span style=''>Online</span> <span style=''>Action</span> <span style='background-color:rgba(0, 255, 0, 0.5331905781584583);'>Detection</span> <span style=''>Forests</span> <span style=''>using</span> <span style=''>Spatio</span> <span style=''>temporal</span> <span style=''>Contexts</span> <br/><br/><span style=''>Online</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.5331905781584583);'>detection</span> <span style=''>(OAD)</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.393483709273183);'>challenging</span> <span style=''>since</span> <span style=''>1)</span> <span style=''>robust</span> <span style=''>yet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>features</span> <span style=''>cannot</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>straightforwardly</span> <span style=''>used</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.4493506493506494);'>processing</span> <span style='background-color:rgba(0, 255, 0, 0.3707865168539326);'>requirements</span> <span style=''>and</span> <span style=''>2)</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>localization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>have</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.39682539682539686);'>performed</span> <span style=''>even</span> <span style=''>before</span> <span style=''>they</span> <span style=''>are</span> <span style=''>fully</span> <span style=''>observed</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>random</span> <span style=''>forest</span> <span style=''>(RF)</span> <span style=''>based</span> <span style=''>online</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.5331905781584583);'>detection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.391304347826087);'>addresses</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenges</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>uses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>skeletal</span> <span style=''>joint</span> <span style=''>features</span> <span style=''>High</span> <span style=''>accuracy</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>using</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.5869565217391304);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(CNN)</span> <span style=''>based</span> <span style=''>features</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>extracted</span> <span style=''>from</span> <span style=''>the</span> <span style=''>raw</span> <span style=''>RGBD</span> <span style=''>images</span> <span style=''>plus</span> <span style=''>the</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>the</span> <span style=''>current</span> <span style=''>frame</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Minimax</span> <span style=''>Manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>We</span> <span style=''>find</span> <span style=''>the</span> <span style=''>minimax</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hausdorff</span> <span style=''>distance</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>a</span> <span style=''>manifold</span> <span style=''>M</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>d</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>RD</span> <span style=''>given</span> <span style=''>a</span> <span style=''>noisy</span> <span style=''>sample</span> <span style=''>from</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>We</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>the</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfies</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothness</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>and</span> <span style=''>that</span> <span style=''>the</span> <span style=''>noise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>has</span> <span style=''>compact</span> <span style=''>support</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>is</span> <span style=''>n</span> <span style=''>2(2d)</span> <span style=''>Thus</span> <span style=''>the</span> <span style=''>minimax</span> <span style=''>rate</span> <span style=''>depends</span> <span style=''>only</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>not</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>space</span> <span style=''>in</span> <span style=''>which</span> <span style=''>M</span> <span style=''>is</span> <span style=''>embedded</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>Hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Diffusion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style=''>Particle</span> <span style=''>Filter</span> <span style=''>vs</span> <span style=''>Modified</span> <span style=''>Baum</span> <span style=''>Welch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>Based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>matrix</span> <span style=''>the</span> <span style=''>Baum</span> <span style=''>Welch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>improved</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>particle</span> <span style=''>filter</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>to</span> <span style=''>the</span> <span style=''>noisy</span> <span style=''>periodic</span> <span style=''>systems</span> <span style=''>It</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style=''>modified</span> <span style=''>Baum</span> <span style=''>Welch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.36190476190476184);'>estimating</span> <span style=''>the</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>with</span> <span style=''>better</span> <span style=''>accuracy</span> <span style=''>than</span> <span style=''>particle</span> <span style=''>filters</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Topic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovery</span> <span style=''>through</span> <span style=''>Data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependent</span> <span style=''>and</span> <span style=''>Random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Projections</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>topic</span> <span style=''>modeling</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>cross</span> <span style=''>document</span> <span style=''>word</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style=''>patterns</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>gains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significance</span> <span style=''>under</span> <span style=''>the</span> <span style=''>so</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>novel</span> <span style=''>words</span> <span style=''>that</span> <span style=''>are</span> <span style=''>unique</span> <span style=''>to</span> <span style=''>each</span> <span style=''>topic</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>suite</span> <span style=''>of</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>based</span> <span style=''>on</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>and</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <span style=''>of</span> <span style=''>word</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style=''>patterns</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>novel</span> <span style=''>words</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>topics</span> <span style=''>We</span> <span style=''>will</span> <span style=''>also</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>two</span> <span style=''>mild</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>prior</span> <span style=''>density</span> <span style=''>of</span> <span style=''>topic</span> <span style=''>document</span> <span style=''>matrix</span> <span style=''>Our</span> <span style=''>key</span> <span style=''>insight</span> <span style=''>here</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>and</span> <span style=''>minimum</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1328820805130032)
# 	segmentation (0.0708941930887068)
# 	knowledge (0.12433202707516922)
# 	architecture (0.08550053437833986)
# 	representation (0.13430708941930888)
# 	information (0.2572141075881724)
# 	detection (0.12753829711435696)
# 	convolutional (0.1300320627003919)
# 	different (0.26433915211970077)
# 	recognition (0.14499465621660135)
#
# Some Statistics words are:
# 	variational (0.10235825388861014)
# 	theoretical (0.14199698946312092)
# 	variables (0.13898645258404416)
# 	estimation (0.17160060210737582)
# 	statistical (0.15955845459106874)
# 	distribution (0.17812343201204214)
# 	dimensional (0.17661816357250376)
# 	algorithm (0.39187155042649274)
# 	regression (0.17912694430506773)
# 	inference (0.20772704465629704)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1d95e786-3a40-460a-9fb7-7532a5910ffb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d95e786-3a40-460a-9fb7-7532a5910ffb")) {                    Plotly.newPlot(                        "1d95e786-3a40-460a-9fb7-7532a5910ffb",                        [{"x":["intelligent","evaluating","requirements","interactive","explicitly","perspective","flexibility","resources","satisfies","describes","portfolios","normative","reasoning","individual","financial","suggesting","involving","extending","architecture","influence","developing","sequential","commercial","construction","decisions","interactively","opportunistic","development","analyzing","explained","blackboard","constructing","encouraging","addressed","management","approaches","collected","supervised","dialogues","answering","optimization","discovering","participant","reinforcement","utterance","predicting","simplistic","algorithm","generating","introduce","architectures","intrinsic","mechanical","framework","concerned","demonstrate","construct","languages","identifying","efficiently","adjectives","efficient","relations","selection","representations","dependency","similarity","configuration","outperform","resulting","configurations","generalise","correlation","effective","particularly","dependencies","representation","universal","previously","automatic","different","approximate","intractable","typically","integration","parameters","algorithms","truncated","minimization","multivariate","approximation","variational","inference","distribution","literature","numerical","integrating","maximization","alternative","experiments","proposals","supervision","embedding","promising","challenging","retrieving","unsupervised","completely","cityscapes","contributions","semantically","objective","represented","currently","correspond","differentiable","clustering","categories","segmentation","retrieval","generation","mechanism","meaningful","unlabeled","objectness","simultaneously","embeddings","dimensional","occurrence","interpretable","interpretability","distinguishes","theoretical","essential","neuroimaging","represent","sufficient","recognition","interpretation","justification","experimental","distinction","depending","prediction","investigates","predictions","sensitive","continuation","techniques","requiring","monitoring","remaining","consistently","outperforms","predictive","completed","certainly","conditional","antecedents","observations","improvement","statements","validated","intuition","hypothetical","counterfactual","antecedent","operations","functions","interested","recurring","variables","automatically","regularization","relevance","stochastic","significantly","contracting","determination","empirical","probabilistic","dimensionality","illustrating","generative","employing","expressive","regression","uncorrelated","principal","responses","predictor","regressors","illustrate","accurately","knowledge","assumption","questions","components","deviations","frequencies","exploiting","addresses","posteriori","interaction","structural","parameterization","structure","iteration","dedicated","estimator","optimized","interestingly","exploited","hyperparameter","improvements","treatment","overfitting","preserving","performance","shortcomings","implementations","competitive","generalized","attention","decomposable","approximations","evaluation","utterances","statement","favorably","interrogative","multimodal","popularly","classification","detecting","recurrent","activation","classifier","originally","detection","sentiment","developed","commentaries","discussions","corresponding","description","captioning","hierarchical","connections","accordingly","microsoft","appropriate","annotation","discont ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	methodologically
# 	competitiveness
# 	multilabel
# 	advantageously
# 	continuing
# 	wirtinger
# 	unforeseen
# 	downweighting
# 	chervonenkis
# 	inversions
# 	ulcerative
# 	zebrafish
# 	transelliptical
# 	elliptical
# 	bootstrapped
# 	majorizer
# 	dermatological
# 	fluctuation
# 	seasonality
# 	corporation
# Some words which never appear in Statistics papers:
# 	blackboard
# 	dialogues
# 	adjectives
# 	cityscapes
# 	certainly
# 	antecedents
# 	utterances
# 	statement
# 	interrogative
# 	commentaries
# 	microsoft
# 	compilation
# 	curriculum
# 	transmitter
# 	autonomously
# 	egocentric
# 	deceptive
# 	colloquial
# 	transformer
# 	sectional

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.056701818737582e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
